# %% [markdown]
# # EDA ON FLIGHT PREDICTION + FEATURE ENGINEERING.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
train_df=pd.read_excel("Data_Train.xlsx")

# %%
test_df=pd.read_excel("Test_set.xlsx")

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
train_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
final_df=train_df.append(test_df)
# Out:
# C:\Users\ANSH MATTOO\AppData\Local\Temp\ipykernel_18064\2547286718.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df=train_df.append(test_df)

# %%
final_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info    Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897.0
# 1    05:50         13:15   7h 25m     2 stops         No info   7662.0
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882.0
# 3    18:05         23:30   5h 25m      1 stop         No info   6218.0
# 4    16:50         21:35   4h 45m      1 stop         No info  13302.0

# %%
final_df.tail()
# Out:
#                 Airline Date_of_Journey   Source Destination            Route  \
# 2666          Air India       6/06/2019  Kolkata    Banglore  CCU → DEL → BLR
# 2667             IndiGo      27/03/2019  Kolkata    Banglore        CCU → BLR
# 2668        Jet Airways       6/03/2019    Delhi      Cochin  DEL → BOM → COK
# 2669          Air India       6/03/2019    Delhi      Cochin  DEL → BOM → COK
# 2670  Multiple carriers      15/06/2019    Delhi      Cochin  DEL → BOM → COK
#
#      Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 2666    20:30  20:25 07 Jun  23h 55m      1 stop         No info    NaN
# 2667    14:20         16:55   2h 35m    non-stop         No info    NaN
# 2668    21:50  04:25 07 Mar   6h 35m      1 stop         No info    NaN
# 2669    04:00         19:15  15h 15m      1 stop         No info    NaN
# 2670    04:55         19:15  14h 20m      1 stop         No info    NaN

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 1.2+ MB

# %%
final_df.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %%
final_df.drop(["Additional_Info"],axis=1,inplace=True)

# %%
final_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops    Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop   3897.0
# 1    05:50         13:15   7h 25m     2 stops   7662.0
# 2    09:25  04:25 10 Jun      19h     2 stops  13882.0
# 3    18:05         23:30   5h 25m      1 stop   6218.0
# 4    16:50         21:35   4h 45m      1 stop  13302.0

# %%
#feature engineering.

# %%
final_df["Date"]=final_df["Date_of_Journey"].str.split("/").str[0]
final_df["Month"]=final_df["Date_of_Journey"].str.split("/").str[1]
final_df["Year"]=final_df["Date_of_Journey"].str.split("/").str[2]

# %%
final_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops    Price Date Month  Year
# 0    22:20  01:10 22 Mar   2h 50m    non-stop   3897.0   24    03  2019
# 1    05:50         13:15   7h 25m     2 stops   7662.0    1    05  2019
# 2    09:25  04:25 10 Jun      19h     2 stops  13882.0    9    06  2019
# 3    18:05         23:30   5h 25m      1 stop   6218.0   12    05  2019
# 4    16:50         21:35   4h 45m      1 stop  13302.0   01    03  2019

# %%
final_df['Date']=final_df['Date'].astype(int)
final_df["Month"]=final_df["Month"].astype(int)
final_df["Year"]=final_df["Year"].astype(int)

# %%
final_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops    Price  Date  Month  Year
# 0    22:20  01:10 22 Mar   2h 50m    non-stop   3897.0    24      3  2019
# 1    05:50         13:15   7h 25m     2 stops   7662.0     1      5  2019
# 2    09:25  04:25 10 Jun      19h     2 stops  13882.0     9      6  2019
# 3    18:05         23:30   5h 25m      1 stop   6218.0    12      5  2019
# 4    16:50         21:35   4h 45m      1 stop  13302.0     1      3  2019

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Price            10683 non-null  float64
#  10  Date             13354 non-null  int32
#  11  Month            13354 non-null  int32
#  12  Year             13354 non-null  int32
# dtypes: float64(1), int32(3), object(9)
# memory usage: 1.3+ MB

# %%
final_df.drop(["Date_of_Journey"],axis=1,inplace=True)

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#    Arrival_Time Duration Total_Stops    Price  Date  Month  Year
# 0  01:10 22 Mar   2h 50m    non-stop   3897.0    24      3  2019
# 1         13:15   7h 25m     2 stops   7662.0     1      5  2019
# 2  04:25 10 Jun      19h     2 stops  13882.0     9      6  2019
# 3         23:30   5h 25m      1 stop   6218.0    12      5  2019
# 4         21:35   4h 45m      1 stop  13302.0     1      3  2019

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Airline       13354 non-null  object
#  1   Source        13354 non-null  object
#  2   Destination   13354 non-null  object
#  3   Route         13353 non-null  object
#  4   Dep_Time      13354 non-null  object
#  5   Arrival_Time  13354 non-null  object
#  6   Duration      13354 non-null  object
#  7   Total_Stops   13353 non-null  object
#  8   Price         10683 non-null  float64
#  9   Date          13354 non-null  int32
#  10  Month         13354 non-null  int32
#  11  Year          13354 non-null  int32
# dtypes: float64(1), int32(3), object(8)
# memory usage: 1.2+ MB

# %%
final_df["Arrival_Time"]=final_df["Arrival_Time"].str.split(' ').str[0]

# %%
# Assuming 'Arrival_Time' is in the format 'HH:mm'
final_df["Arrival_hour"]=final_df['Arrival_Time'].str.split(':').str[0]
final_df["Arrival_min"]=final_df['Arrival_Time'].str.split(':').str[1]

# %%
final_df['Arrival_hour'] = final_df['Arrival_hour'].astype(int)
final_df['Arrival_min'] = final_df['Arrival_min'].astype(int)

# %%
 final_df.isnull().sum()
# Out:
# Airline            0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Price           2671
# Date               0
# Month              0
# Year               0
# Arrival_hour       0
# Arrival_min        0
# dtype: int64

# %%
#dealing with null values means replacing with the  the mode
final_df["Total_Stops"]=final_df["Total_Stops"].fillna(final_df["Total_Stops"].mode()[0])

# %%
final_df["Route"]=final_df["Route"].fillna(final_df["Route"].mode()[0])

# %%
final_df.isnull().sum()
# Out:
# Airline            0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Price           2671
# Date               0
# Month              0
# Year               0
# Arrival_hour       0
# Arrival_min        0
# dtype: int64

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Airline       13354 non-null  object
#  1   Source        13354 non-null  object
#  2   Destination   13354 non-null  object
#  3   Route         13354 non-null  object
#  4   Dep_Time      13354 non-null  object
#  5   Arrival_Time  13354 non-null  object
#  6   Duration      13354 non-null  object
#  7   Total_Stops   13354 non-null  object
#  8   Price         10683 non-null  float64
#  9   Date          13354 non-null  int32
#  10  Month         13354 non-null  int32
#  11  Year          13354 non-null  int32
#  12  Arrival_hour  13354 non-null  int32
#  13  Arrival_min   13354 non-null  int32
# dtypes: float64(1), int32(5), object(8)
# memory usage: 1.3+ MB

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Total_Stops    Price  Date  Month  Year  Arrival_hour  \
# 0        01:10   2h 50m    non-stop   3897.0    24      3  2019             1
# 1        13:15   7h 25m     2 stops   7662.0     1      5  2019            13
# 2        04:25      19h     2 stops  13882.0     9      6  2019             4
# 3        23:30   5h 25m      1 stop   6218.0    12      5  2019            23
# 4        21:35   4h 45m      1 stop  13302.0     1      3  2019            21
#
#    Arrival_min
# 0           10
# 1           15
# 2           25
# ...

# %%
final_df.drop(["Arrival_Time"],axis=1,inplace=True)

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50   4h 45m
#
#   Total_Stops    Price  Date  Month  Year  Arrival_hour  Arrival_min
# 0    non-stop   3897.0    24      3  2019             1           10
# 1     2 stops   7662.0     1      5  2019            13           15
# 2     2 stops  13882.0     9      6  2019             4           25
# 3      1 stop   6218.0    12      5  2019            23           30
# 4      1 stop  13302.0     1      3  2019            21           35

# %%
final_df["Dep_Hour"]=final_df["Dep_Time"].str.split(":").str[0]
final_df["Dep_Min"]=final_df["Dep_Time"].str.split(":").str[1]

# %%
final_df["Dep_Hour"].astype(int)
# Out:
# 0       22
# 1        5
# 2        9
# 3       18
# 4       16
#         ..
# 2666    20
# 2667    14
# 2668    21
# 2669     4
# 2670     4
# Name: Dep_Hour, Length: 13354, dtype: int32

# %%
final_df["Dep_Min"].astype(int)
# Out:
# 0       20
# 1       50
# 2       25
# 3        5
# 4       50
#         ..
# 2666    30
# 2667    20
# 2668    50
# 2669     0
# 2670    55
# Name: Dep_Min, Length: 13354, dtype: int32

# %%
final_df.drop("Dep_Time",axis=1,inplace=True)

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#   Total_Stops    Price  Date  Month  Year  Arrival_hour  Arrival_min Dep_Hour  \
# 0    non-stop   3897.0    24      3  2019             1           10       22
# 1     2 stops   7662.0     1      5  2019            13           15       05
# 2     2 stops  13882.0     9      6  2019             4           25       09
# 3      1 stop   6218.0    12      5  2019            23           30       18
# 4      1 stop  13302.0     1      3  2019            21           35       16
#
#   Dep_Min
# 0      20
# 1      50
# 2      25
# 3      05
# 4      50

# %%
final_df.isnull().sum()
# Out:
# Airline            0
# Source             0
# Destination        0
# Route              0
# Duration           0
# Total_Stops        0
# Price           2671
# Date               0
# Month              0
# Year               0
# Arrival_hour       0
# Arrival_min        0
# Dep_Hour           0
# Dep_Min            0
# dtype: int64

# %%
final_df["Total_Stops"] = final_df["Total_Stops"].map({'non-stop':0,'2 stops':1,'1 stop':2,'3 stops':3,'4 stops':4,})

# %%
final_df["Total_Stops"].unique()
# Out:
# array([0, 1, 2, 3, 4], dtype=int64)

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#    Total_Stops    Price  Date  Month  Year  Arrival_hour  Arrival_min  \
# 0            0   3897.0    24      3  2019             1           10
# 1            1   7662.0     1      5  2019            13           15
# 2            1  13882.0     9      6  2019             4           25
# 3            2   6218.0    12      5  2019            23           30
# 4            2  13302.0     1      3  2019            21           35
#
#   Dep_Hour Dep_Min
# 0       22      20
# 1       05      50
# 2       09      25
# 3       18      05
# 4       16      50

# %%
final_df["Total_Stops"].isnull().sum()
# Out:
# 0

# %%
final_df.drop(["Route"],axis=1,inplace=True)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Airline       13354 non-null  object
#  1   Source        13354 non-null  object
#  2   Destination   13354 non-null  object
#  3   Duration      13354 non-null  object
#  4   Total_Stops   13354 non-null  int64
#  5   Price         10683 non-null  float64
#  6   Date          13354 non-null  int32
#  7   Month         13354 non-null  int32
#  8   Year          13354 non-null  int32
#  9   Arrival_hour  13354 non-null  int32
#  10  Arrival_min   13354 non-null  int32
#  11  Dep_Hour      13354 non-null  object
#  12  Dep_Min       13354 non-null  object
# dtypes: float64(1), int32(5), int64(1), object(6)
# memory usage: 1.2+ MB

# %%
final_df.drop(["Duration"],axis=1,inplace=True)

# %%
final_df.head()
# Out:
#        Airline    Source Destination  Total_Stops    Price  Date  Month  Year  \
# 0       IndiGo  Banglore   New Delhi            0   3897.0    24      3  2019
# 1    Air India   Kolkata    Banglore            1   7662.0     1      5  2019
# 2  Jet Airways     Delhi      Cochin            1  13882.0     9      6  2019
# 3       IndiGo   Kolkata    Banglore            2   6218.0    12      5  2019
# 4       IndiGo  Banglore   New Delhi            2  13302.0     1      3  2019
#
#    Arrival_hour  Arrival_min Dep_Hour Dep_Min
# 0             1           10       22      20
# 1            13           15       05      50
# 2             4           25       09      25
# 3            23           30       18      05
# 4            21           35       16      50

# %%
#now handle the categorical variables
from sklearn.preprocessing import LabelEncoder

# %%
final_df["Airline"].unique()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %%
encoder=LabelEncoder()

# %%
final_df["Airline"]=encoder.fit_transform(final_df['Airline'])
final_df["Source"]=encoder.fit_transform(final_df["Source"])
final_df["Destination"]=encoder.fit_transform(final_df["Destination"])

# %%
final_df.shape
# Out:
# (13354, 12)

# %%
final_df.head()
# Out:
#    Airline  Source  Destination  Total_Stops    Price  Date  Month  Year  \
# 0        3       0            5            0   3897.0    24      3  2019
# 1        1       3            0            1   7662.0     1      5  2019
# 2        4       2            1            1  13882.0     9      6  2019
# 3        3       3            0            2   6218.0    12      5  2019
# 4        3       0            5            2  13302.0     1      3  2019
#
#    Arrival_hour  Arrival_min Dep_Hour Dep_Min
# 0             1           10       22      20
# 1            13           15       05      50
# 2             4           25       09      25
# 3            23           30       18      05
# 4            21           35       16      50
